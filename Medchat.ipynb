# %% [markdown]
# # **试试基础模型**

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# 指定模型名称
model_name = "BioMistral/BioMistral-7B"

# 加载模型和分词器
model = AutoModelForCausalLM.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

def chat_with_model(question):
    """ 使用模型回答医学问题 """
    inputs = tokenizer(question, return_tensors="pt")
    outputs = model.generate(**inputs, max_length=100)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# 测试模型
question = "What are the symptoms of pneumonia?"
response = chat_with_model(question)
print("BioMistral Answer:", response)

# %%
def chat_with_model(question):
    """ 让医学模型回答问题 """
    inputs = tokenizer(question, return_tensors="pt")

    outputs = model.generate(
        **inputs,
        max_length=100,
        temperature=0.7,  # 控制生成的随机性
        top_p=0.9,  # 限制采样范围
        do_sample=True  # 让回答更自然
    )

    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# 测试改进后的生成方法
question = "What are the symptoms of having a fever?"
response = chat_with_model(question)
print("Improved Model Answer:", response)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Improved Model Answer: What are the symptoms of having a fever? It is an abnormal increase in body temperature, usually measured above 37.8°C (100°F) . Fever is a common symptom of many diseases, but it is not a disease by itself. Most fevers are caused by infections, such as viruses, bacteria, or parasites. Other causes of fever can be due to non-infectious conditions such as tissue damage, malignancy
